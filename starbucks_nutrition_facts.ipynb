# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style("darkgrid")

# %%
df = pd.read_csv(r"C:\db\starbucks.csv",index_col=0)

# %%
df.head()
# Out:
#                           item  calories   fat  carb  fiber  protein    type
# 1                 8-Grain Roll       350   8.0    67      5       10  bakery
# 2            Apple Bran Muffin       350   9.0    64      7        6  bakery
# 3                Apple Fritter       420  20.0    59      0        5  bakery
# 4              Banana Nut Loaf       490  19.0    75      4        7  bakery
# 5  Birthday Cake Mini Doughnut       130   6.0    17      0        0  bakery

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, 1 to 77
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   item      77 non-null     object
#  1   calories  77 non-null     int64
#  2   fat       77 non-null     float64
#  3   carb      77 non-null     int64
#  4   fiber     77 non-null     int64
#  5   protein   77 non-null     int64
#  6   type      77 non-null     object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#          calories        fat       carb      fiber    protein
# count   77.000000  77.000000  77.000000  77.000000  77.000000
# mean   338.831169  13.766234  44.870130   2.220779   9.480519
# std    105.368701   7.095488  16.551634   2.112764   8.079556
# min     80.000000   0.000000  16.000000   0.000000   0.000000
# 25%    300.000000   9.000000  31.000000   0.000000   5.000000
# 50%    350.000000  13.000000  45.000000   2.000000   7.000000
# 75%    420.000000  18.000000  59.000000   4.000000  15.000000
# max    500.000000  28.000000  80.000000   7.000000  34.000000

# %%
df["item"].nunique()
# Out:
# 77

# %%
df["item"].unique()
# Out:
# array(['8-Grain Roll', 'Apple Bran Muffin', 'Apple Fritter',
#        'Banana Nut Loaf', 'Birthday Cake Mini Doughnut',
#        'Blueberry Oat Bar', 'Blueberry Scone',
#        'Bountiful Blueberry Muffin', 'Butter Croissant ', 'Cheese Danish',
#        'Chocolate Chunk Cookie', 'Chocolate Cinnamon Bread',
#        'Chocolate Croissant', 'Chocolate Old-Fashioned Doughnut',
#        'Chonga Bagel', 'Cinnamon Chip Scone', 'Cranberry Orange Scone',
#        'Double Chocolate Brownie', 'Double Fudge Mini Doughnut',
#        'Everything with Cheese Bagel', 'Ginger Molasses Cookie',
#        'Iced Lemon Pound Cake', 'Mallorca Sweet Bread',
#        'Maple Oat Pecan Scone ', 'Marble Pound Cake',
#        'Marshmallow Dream Bar', 'Morning Bun', 'Multigrain Bagel',
#        'Old-Fashioned Glazed Doughnut', 'Outrageous Oatmeal Cookie',
#        'Petite Vanilla Bean Scone', 'Plain Bagel', 'Pumpkin Bread',
#        'Pumpkin Scone ', 'Raspberry Scone', 'Raspberry Swirl Pound Cake',
# ...

# %%
df.groupby("type")["item"].count()
# Out:
# type
# bakery           41
# bistro box        8
# hot breakfast     8
# parfait           3
# petite            9
# salad             1
# sandwich          7
# Name: item, dtype: int64

# %%
df.groupby("type")["item"].count().plot()
plt.title("Product Types")
plt.text(0.,50,"product-category graph",bbox=dict(facecolor="yellow",alpha=0.5))
plt.show()

# %%
sns.countplot(x="type",data=df,palette="Set3")
plt.title("Number of products")
plt.show()
# Out:
# C:\Users\ENİSE AHSEN\AppData\Local\Temp\ipykernel_17180\2080200531.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="type",data=df,palette="Set3")

# %%
sns.catplot(kind="bar",x="type",y="calories",data=df,palette="Set3")
plt.title("Calorie Values")
plt.show()
# Out:
# C:\Users\ENİSE AHSEN\AppData\Local\Temp\ipykernel_17180\992846813.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(kind="bar",x="type",y="calories",data=df,palette="Set3")

# %%
sns.catplot(kind="bar",x="type",y="protein",data=df,palette="Set3")
plt.title("Protein Values")
plt.show()
# Out:
# C:\Users\ENİSE AHSEN\AppData\Local\Temp\ipykernel_17180\3006073306.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(kind="bar",x="type",y="protein",data=df,palette="Set3")

# %%
sns.catplot(kind="bar",x="type",y="carb",data=df,palette="Set3")
plt.title("Calorie Values")
plt.show()
# Out:
# C:\Users\ENİSE AHSEN\AppData\Local\Temp\ipykernel_17180\1548099973.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(kind="bar",x="type",y="carb",data=df,palette="Set3")

# %%
sns.catplot(kind="bar",x="type",y="fiber",data=df,palette="Set3")
plt.title("Calorie Values")
plt.show()
# Out:
# C:\Users\ENİSE AHSEN\AppData\Local\Temp\ipykernel_17180\4237764971.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(kind="bar",x="type",y="fiber",data=df,palette="Set3")

# %%
numeric_df = df.select_dtypes(include=[np.number])
correlation_matrix = numeric_df.corr()
print(correlation_matrix)
# Out:
#           calories       fat      carb     fiber   protein
# calories  1.000000  0.758682  0.674999  0.260645  0.410398
# fat       0.758682  1.000000  0.144547 -0.028549  0.223470
# carb      0.674999  0.144547  1.000000  0.213044 -0.050789
# fiber     0.260645 -0.028549  0.213044  1.000000  0.488564
# protein   0.410398  0.223470 -0.050789  0.488564  1.000000

# %%
sns.heatmap(correlation_matrix,annot=True)
# Out:
# <Axes: >

# %%
plt.title("Calories and Fat")
sns.scatterplot(x="calories",y="fat",data=df,s=30,edgecolor="red")
plt.plot()
# Out:
# []

# %%
sns.displot(x="calories",data=df,color="pink",kde=True)
plt.title("Calories Graph")
plt.show()

# %%
sns.displot(x="protein",data=df,color="blue",kde=True)
plt.title("Protein Graph")
plt.show()

# %%
sns.displot(x="fat",data=df,color="green",kde=True)
plt.title("Fat Graph")
plt.show()

# %%
df.head()
# Out:
#                           item  calories   fat  carb  fiber  protein    type
# 1                 8-Grain Roll       350   8.0    67      5       10  bakery
# 2            Apple Bran Muffin       350   9.0    64      7        6  bakery
# 3                Apple Fritter       420  20.0    59      0        5  bakery
# 4              Banana Nut Loaf       490  19.0    75      4        7  bakery
# 5  Birthday Cake Mini Doughnut       130   6.0    17      0        0  bakery

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
x = df[["calories","fat","carb","fiber","protein"]]
y = df[["type"]]

# %%
x
# Out:
#     calories   fat  carb  fiber  protein
# 1        350   8.0    67      5       10
# 2        350   9.0    64      7        6
# 3        420  20.0    59      0        5
# 4        490  19.0    75      4        7
# 5        130   6.0    17      0        0
# ..       ...   ...   ...    ...      ...
# 73       420  13.0    46      6       32
# 74       390  13.0    36      2       34
# 75       300  12.0    44      0        8
# 76       300   4.0    57      3       10
# 77       300   3.5    60      3        7
#
# [77 rows x 5 columns]

# %%
y
# Out:
#         type
# 1     bakery
# 2     bakery
# 3     bakery
# 4     bakery
# 5     bakery
# ..       ...
# 73  sandwich
# 74  sandwich
# 75   parfait
# 76   parfait
# 77   parfait
#
# [77 rows x 1 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model =DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=model.predict(x_test)

# %%
accuracy =accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.6875

# %%
df
# Out:
#                                      item  calories   fat  carb  fiber  \
# 1                            8-Grain Roll       350   8.0    67      5
# 2                       Apple Bran Muffin       350   9.0    64      7
# 3                           Apple Fritter       420  20.0    59      0
# 4                         Banana Nut Loaf       490  19.0    75      4
# 5             Birthday Cake Mini Doughnut       130   6.0    17      0
# ..                                    ...       ...   ...   ...    ...
# 73        Tarragon Chicken Salad Sandwich       420  13.0    46      6
# 74                Turkey & Swiss Sandwich       390  13.0    36      2
# 75             Greek Yogurt Honey Parfait       300  12.0    44      0
# 76         Peach Raspberry Yogurt Parfait       300   4.0    57      3
# 77  Strawberry & Blueberry Yogurt Parfait       300   3.5    60      3
#
#     protein      type
# 1        10    bakery
# 2         6    bakery
# 3         5    bakery
# ...

# %%
prediction = model.predict([[150,2,4,7,29]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
prediction
# Out:
# array(['bistro box'], dtype=object)

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(15,10))
plot_tree(model,feature_names=x.columns,class_names=model.classes_,filled=True)
plt.show()

# %%
type_st = df["type"].value_counts()
plt.figure(figsize=(10,10))
plt.title("Products types")
plt.pie(data=df,x=type_st.values,labels=type_st.index,autopct="%1.1f%%", explode=(0.1,0,0,0,0,0,0),shadow=True)
plt.show()

# %%
df.sort_values("calories",ascending=False).head(10)
# Out:
#                                             item  calories   fat  carb  fiber  \
# 62  Sausage & Cheddar Classic Breakfast Sandwich       500  28.0    41      0
# 22                         Iced Lemon Pound Cake       490  23.0    67      0
# 4                                Banana Nut Loaf       490  19.0    75      4
# 41                       Zucchini Walnut Muffin        490  28.0    52      2
# 17                        Cranberry Orange Scone       490  18.0    73      2
# 16                           Cinnamon Chip Scone       480  18.0    70      3
# 34                                Pumpkin Scone        480  17.0    78      2
# 42                                Cheese & Fruit       480  28.0    39      6
# 35                               Raspberry Scone       480  25.0    59      3
# 7                                Blueberry Scone       460  22.0    61      2
#
#     protein           type
# 62       19  hot breakfast
# 22        5         bakery
# ...
